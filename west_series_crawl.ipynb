# %% [markdown]
# # PTT NBA版 球迷推文爬蟲

# %% [markdown]
# 載入爬蟲套件

# %%
import requests
from bs4 import BeautifulSoup
import json
import itertools as it
import string

# %% [markdown]
# 爬取PTT-2018 NBA西區季後系列賽實況文

# %%
#系列戰1
url_west0 = 'https://www.ptt.cc/bbs/NBA/M.1523730663.A.801.html'
url_west1 = 'https://www.ptt.cc/bbs/NBA/M.1523930402.A.127.html'
url_west2 = 'https://www.ptt.cc/bbs/NBA/M.1524186002.A.2CE.html'
url_west3 = 'https://www.ptt.cc/bbs/NBA/M.1524423604.A.351.html'
url_west4 = 'https://www.ptt.cc/bbs/NBA/M.1524621603.A.740.html'

#系列戰2
url_west5 = 'https://www.ptt.cc/bbs/NBA/M.1524967203.A.44C.html'
url_west6 = 'https://www.ptt.cc/bbs/NBA/M.1525226402.A.FC1.html'
url_west7 = 'https://www.ptt.cc/bbs/NBA/M.1525476604.A.6F7.html'
url_west8 = 'https://www.ptt.cc/bbs/NBA/M.1525633208.A.221.html'
url_west9 = 'https://www.ptt.cc/bbs/NBA/M.1525831203.A.73A.html'

#系列戰3
url_west10 = 'https://www.ptt.cc/bbs/NBA/M.1526344205.A.F7A.html'
url_west11 = 'https://www.ptt.cc/bbs/NBA/M.1526517004.A.404.html'
url_west12 = 'https://www.ptt.cc/bbs/NBA/M.1526859003.A.02C.html'
url_west13 = 'https://www.ptt.cc/bbs/NBA/M.1527035404.A.01E.html'
url_west14 = 'https://www.ptt.cc/bbs/NBA/M.1527208202.A.11C.html'
url_west15 = 'https://www.ptt.cc/bbs/NBA/M.1527381003.A.1D1.html'
url_west16 = 'https://www.ptt.cc/bbs/NBA/M.1527553804.A.1AF.html'


res = requests.get(url_west10)
soup = BeautifulSoup(res.text,'html.parser')

# %% [markdown]
# 只保留鄉民推文的內容

# %%
s= []
data_inner = soup.find_all(class_="f3 push-content")
for item in data_inner:
        s.append(str(item.string)[1:])

# %% [markdown]
# 紀錄勇士隊員的別名稱呼

# %%
warrior = ['warrior','勇','Warrior']
kerr = ['kerr','Kerr','勇士教練','KERR']
g = ['DG','green','Green','嘴綠','髒綠','格林']
kd = ['KD','kd','揪杜蘭','雷帝','舒適','杯子蛋糕','腿肚','蘭特','圓仔','腿杜']
kt = ['KT','kt','Kt','K湯','佛祖','魔界之王','披薩','分身','湯神']
curry = ['curry','Curry','咖','萌神','浪花哥','路人','科呂','柯']
ai = ['Iguodala','ai','AI','iggy','Iggy','伊古達拉']
ln = ['Looney ','looney','魯尼']
bell = ['Bell',]
young =['黑人問號','小老大','尖','swaggy','nick young','Nick Young']
li= ['Livingston','李文',]
caw  = ['McCaw','馬尻']
west = ['David West','大衛西']
mcgee = ['McGee','my boy','麥基']
cook = ['cook']
zaza = ['Pachulia','zaza','ZAZA','Zaza','喳喳','2a2a']

# %% [markdown]
# 紀錄火箭隊員的別名稱呼

# %%
rockets = ['Rocket','rocket','休士頓','火箭','火']
Michael = ['Michael']
Ariza = ['Ariza','ARIZA','亞瑞莎','阿雷薩','阿里沙','ariza']
Tucker = ['Tucker','塔克','PJ','pj','Tiger','tucker']
Capela = ['Capela','CAPELA','卡佩拉','餅','魚住','capela']
Harden = ['Harden','harden','鬍','買飯','哈登','哈燈','燈','James','糊子']
Paul = ['Paul','paul','pg','CP3','Cp3','cp3','保羅','Chris Paul']
Gordon = ['Gordon','狗蛋','狗等','gordon']
Mout = ['Moute','木鐵']
GGreen = ['GGreen','gg','gerald','火箭green']
Anderson = ['Anderson','anderson']
Nene = ['Nene','nene']
Black = ['Black','black']
Jackson = ['Jackson','jackson','傑克森']
Johnson = ['Johnson','秋江嬸','強森']
qi = ['Qi','zhou','周','琦']

# %% [markdown]
# 記錄壞詞庫

# %%
bad = ['雷','放槍','超鐵','打鐵','埋','蛹','垃圾','髒','黑','假摔','犯規','勾腳','酸','廢','廁所','爛','弱','幹','恍']

# %% [markdown]
# 1)記錄球員被題及次數
# 2)記錄球員差評次數

# %%
warrior_count = 0
kerr_count= 0
g_count = 0
kt_count = 0
curry_count = 0
kd_count = 0
ai_count = 0
ln_count = 0
bell_count = 0
young_count = 0
li_count = 0
caw_count = 0
west_count = 0
mcgee_count = 0
cook_count = 0
zaza_count = 0

warrior_bad = 0
kerr_bad= 0
g_bad = 0
kt_bad = 0
curry_bad = 0
kd_bad = 0
ai_bad = 0
ln_bad = 0
bell_bad = 0
young_bad = 0
li_bad = 0
caw_bad = 0
west_bad = 0
mcgee_bad = 0
cook_bad = 0
zaza_bad = 0

for i in s:
    for e in warrior:
        if e in i:
            #print(i)
            warrior_count+=1
            for b in bad:
                 if b in i:
                    #print(i)
                    warrior_bad+=1
            
            
    for e in kerr:
        if e in i:
            #print(i)
            kerr_count+=1
            for b in bad:
                 if b in i:
                    #print(i)
                    kerr_bad+=1
    for e in g:
        if e in i:
            #print(i)
            g_count+=1
            for b in bad:
                 if b in i:
                    #print(i)
                    g_bad+=1
            
    for e in kt:
        if e in i:
            #print(i)
            kt_count+=1
            for b in bad:
                 if b in i:
                    #print(i)
                    kt_bad+=1
            
    for e in curry:
        if e in i:
            curry_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    curry_bad+=1
            
    for e in kd:
        if e in i:
            #print(i)
            kd_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    kd_bad+=1
            
    for e in ai:
        if e in i:
            #print(i)
            ai_count+=1    
            for b in bad:
                if b in i:
                    #print(i)
                    ai_bad+=1
            
    for e in ln:
        if e in i:
            #print(i)
            ln_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    ln_bad+=1
                    
    for e in li:
        if e in i:
            #print(i)
            li_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    li_bad+=1
            
    for e in bell:
        if e in i:
            #print(i)
            bell_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    bell_bad+=1
            
    for e in young:
        if e in i:
            #print(i)
            young_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    young_bad+=1
            
    for e in caw:
        if e in i:
            #print(i)
            caw_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    caw_bad+=1
            
    for e in west:
        if e in i:
            #print(i)
            west_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    west_bad+=1
            
    for e in mcgee:
        if e in i:
            #print(i)
            mcgee_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    mcgee_bad+=1
            
    for e in cook:
        if e in i:
            #print(i)
            cook_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    cook_bad+=1
            
    for e in zaza:
        if e in i:
            #print(i)
            zaza_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    zaza_bad+=1
            

warrior_count = warrior_count - warrior_bad
kerr_count = kerr_count - kerr_bad 
kd_count = kd_count - kd_bad 
g_count = g_count - g_bad 
bell_count = bell_count - bell_bad 
curry_count = curry_count - curry_bad 
kt_count = kt_count - kt_bad 
ai_count = ai_count - ai_bad 
ln_count = ln_count - ln_bad 
young_count = young_count - young_bad 
li_count = li_count - li_bad 
caw_count = caw_count - caw_bad 
west_count = west_count - west_bad 
mcgee_count = mcgee_count - mcgee_bad 
cook_count = cook_count - cook_bad 
zaza_count = zaza_count - zaza_bad 

print("隊名","教練","K. Durant","D. Green","J. Bell","S. Curry","K. Thompson",
      "A. Iguodala","K. Looney","Livingston","N. Young",
      " P. McCaw","D. West","J. McGee" ,"Q. Cook","Z. Pachulia")
print(warrior_count,
kerr_count,
kd_count,      
g_count,
bell_count,  
curry_count,      
kt_count,
ai_count,
ln_count,
young_count,
li_count,
caw_count,
west_count,
mcgee_count,
cook_count,
zaza_count,)

print(warrior_bad ,
kerr_bad,
kd_bad,
g_bad,
bell_bad,      
curry_bad,
kt_bad ,
ai_bad,
ln_bad,
young_bad,
li_bad,
caw_bad ,
west_bad ,
mcgee_bad ,
cook_bad ,
)
# Out:
# 隊名 教練 K. Durant D. Green J. Bell S. Curry K. Thompson A. Iguodala K. Looney Livingston N. Young  P. McCaw D. West J. McGee Q. Cook Z. Pachulia
# 175 0 96 69 0 69 18 7 21 7 0 0 0 0 0 17
# 64 1 4 22 0 7 0 0 4 2 0 0 0 0 0

# %% [markdown]
# # Rockets

# %%
rockets_count = 0
Michael_count = 0 
Ariza_count = 0
Tucker_count = 0
Capela_count = 0
Harden_count = 0
Paul_count = 0
Gordon_count = 0 
Mout_count = 0
GGreen_count = 0
Anderson_count = 0
Nene_count = 0
Black_count = 0
Jackson_count = 0 
Johnson_count = 0 
qi_count = 0

rockets_bad = 0
Michael_bad= 0
Ariza_bad = 0
Capela_bad = 0
Tucker_bad = 0
Harden_bad = 0
Paul_bad = 0
Gordon_bad = 0
Mout_bad = 0
GGreen_bad = 0
Anderson_bad = 0
Nene_bad = 0
Black_bad = 0
Jackson_bad = 0
Johnson_bad = 0
qi_bad = 0

for i in s:
    for e in rockets:
        if e in i:
            #print(i)
            rockets_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    rockets_bad+=1
     
    for e in Michael:
        if e in i:
            #print(i)
            Michael_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Michael_bad+=1
    for e in Ariza:
        if e in i:
            #print(i)
            Ariza_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Ariza_bad+=1
    for e in Tucker:
        if e in i:
            #print(i)
            Tucker_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Tucker_bad+=1
    for e in Capela:
        if e in i:
            Capela_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Capela_bad+=1
    for e in Harden:
        if e in i:
            #print(i)
            Harden_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Harden_bad+=1
    for e in Paul:
        if e in i:
            #print(i)
            Paul_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Paul_bad+=1
    for e in Gordon:
        if e in i:
            #print(i)
            Gordon_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Gordon_bad+=1
    for e in Mout:
        if e in i:
            #print(i)
            Mout_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Mout_bad+=1
    for e in GGreen:
        if e in i:
            #print(i)
            GGreen_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    GGreen_bad+=1
    for e in Anderson:
        if e in i:
            #print(i)
            Anderson_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Anderson_bad+=1
    for e in Jackson:
        if e in i:
            #print(i)
            Jackson_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Jackson_bad+=1
    for e in Nene:
        if e in i:
            #print(i)
            Nene_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Nene_bad+=1
    for e in Black:
        if e in i:
            #print(i)
            Black_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Black_bad+=1
    for e in Johnson:
        if e in i:
            #print(i)
            Johnson_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    Johnson_bad+=1
    for e in qi:
        if e in i:
            #print(i)
            qi_count+=1
            for b in bad:
                if b in i:
                    #print(i)
                    qi_bad+=1

                    
rockets_count = rockets_count -rockets_bad
Michael_count = Michael_count-Michael_bad
Ariza_count = Ariza_count-Ariza_bad
Tucker_count = Tucker_count-Tucker_bad
Capela_count = Capela_count -Capela_bad
Harden_count = Harden_count-Harden_bad
Paul_count = Paul_count-Paul_bad
Gordon_count = Gordon_count-Gordon_bad 
Mout_count = Mout_count-Mout_bad
GGreen_count = GGreen_count-GGreen_bad
Anderson_count = Anderson_count-Anderson_bad 
Nene_count = Nene_count-Nene_bad
Black_count = Black_count-Black_bad
Jackson_count = Jackson_count-Jackson_bad 
Johnson_count = Johnson_count-Johnson_bad
qi_count = qi_count-qi_bad
                    
print("隊名","教練","T. Ariza","P. Tucker","C. Capela","J. Harden","C. Paul",
      "E. Gordon","Mbah a Mout","G. Green ","R. Anderson",
      "Nene","T. Black","A. Jackson" ,"J. Johnson","Z. Qi")
print(rockets_count,
Michael_count,
Ariza_count,
Tucker_count,
Capela_count,
Harden_count,
Paul_count,
Gordon_count,
Mout_count,
GGreen_count,
Anderson_count,
Nene_count,
Black_count,
Jackson_count, 
Johnson_count,
qi_count,)

print(rockets_bad,
Michael_bad,
Ariza_bad,
Tucker_bad,
Capela_bad,
Harden_bad,
Paul_bad,
Gordon_bad ,
Mout_bad,
GGreen_bad ,
Anderson_bad ,
Nene_bad ,
Black_bad ,
Jackson_bad ,
Johnson_bad,
qi_bad,
)
# Out:
# 隊名 教練 T. Ariza P. Tucker C. Capela J. Harden C. Paul E. Gordon Mbah a Mout G. Green  R. Anderson Nene T. Black A. Jackson J. Johnson Z. Qi
# 269 0 5 14 16 146 61 7 1 2 0 0 0 0 0 0
# 23 0 5 2 0 11 11 0 2 0 0 0 0 0 0 0
